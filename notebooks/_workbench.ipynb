# %%
from post_roe.query import BucketQuery as bq

states = bq.states_query(status=['not_protected'])
states
# Out:
#    state                        _status_wp  census_total        _status
# 0     VT  Legal and likely to be protected        623926      protected
# 1     HI  Legal and likely to be protected       1360211      protected
# 2     RI  Legal and likely to be protected       1048130      protected
# 3     MA  Legal and likely to be protected       6546256      protected
# 4     MD  Legal and likely to be protected       5761485      protected
# 5     ME  Legal and likely to be protected       1327190      protected
# 6     AK  Legal and likely to be protected        695391      protected
# 7     OR  Legal and likely to be protected       3858150      protected
# 8     NV  Legal and likely to be protected       2669598      protected
# 9     NH  Legal and likely to be protected       1316271      protected
# 10    IL  Legal and likely to be protected      12829715      protected
# 11    MN  Legal and likely to be protected       5310207      protected
# ...
